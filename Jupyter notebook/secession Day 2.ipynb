# %%
# body mass index (BMI)
# input weight
# weight
# (BMI) Ask your self height
# weight
# calculate BMI
# print BMI (My name is ....., and my BMI is.....)

# %%
# weight in Kg/height in m and its square

# %%
height = input("what is your height? ")
# Out:
# what is your height?  1.65

# %% [markdown]
# height = input("what is your height? ")
# height= float(height)
# weight = input("what is your weight? ")
# weight= float(weight)
# BMI = weight/height**2
# print("my name is", "and my BMI is", BMI)

# %%
height= float(height)

# %%
weight = input("what is your weight? ")
# Out:
# what is your weight?  75

# %%
weight= float(weight)

# %%
name = input("what is your name? ")
# Out:
# what is your name?  Ahmad

# %% [markdown]
# BMI = weight/height**2
# print =BMI

# %%
print("my name is", "and my BMI is", BMI)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print("my name is", "and my BMI is", BMI)
#
# NameError: name 'BMI' is not defined

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="ticks", color_codes=True)

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind= "bar", data=titanic)
plt.show()

# %%
p1=sns.countplot(x='sex', data=titanic, hue='class')
p1.set_title("plot for couting")
plt.show()

# %%
g=sns.FacetGrid(titanic, row="sex", hue="alone")
g=(g.map(plt.scatter,"age", "fare").add_legend())
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes="True")
kashti= sns.load_dataset("titanic")
p=sns.countplot(x="sex", data=kashti) #with one variable (count)
p=sns.countplot(x="sex", data=kashti, hue="class") # with two variable(count plot)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes="True")
kashti= sns.load_dataset("titanic")
p=sns.countplot(x="sex", data=kashti) #with one variable (count)
p=sns.countplot(x="sex", data=kashti, hue="class") # with two variable(count plot)
plt.show()

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes="True")
kashti= sns.load_dataset("titanic")
p=sns.countplot(x="sex", data=kashti) #with one variable (count)
p=sns.countplot(x="sex", data=kashti, hue="class") # with two variable(count plot) with title
p.set_title("Baba_Ammar ka chilla for count plot for title")
plt.show()

# %%
### indexing in tuple###

# %%
tupl1 = (1, "python", True, 2.5)
tupl1
# Out:
# (1, 'python', True, 2.5)

# %%
# type of tuple
type(tupl1)
# Out:
# tuple
